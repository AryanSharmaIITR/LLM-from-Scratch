# %%
with open("../data/the_verdict.txt","r") as f:
    raw_text = f.read()

# %%
import regex as re
gpt4=re.compile(r"""'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+""")

# %%
print(re.findall(gpt4,"Building TOkenizer of Gpt4!"))
# Out:
# ['Building', ' TOkenizer', ' of', ' Gpt', '4', '!']

# %%
preprocessed=re.findall(gpt4,raw_text)

# %%
len(preprocessed)
# Out:
# 4538

# %%
def get_stats(words):
    counts={}
    for ids in words:
        for pair in zip(ids,ids[1:]):
            counts[pair]=counts.get(pair,0)+1
    return counts

# %%
get_stats(['Building', ' TOkenizer', ' of', ' Gpt', '4', '!'])
# Out:
# {('B', 'u'): 1,
#  ('u', 'i'): 1,
#  ('i', 'l'): 1,
#  ('l', 'd'): 1,
#  ('d', 'i'): 1,
#  ('i', 'n'): 1,
#  ('n', 'g'): 1,
#  (' ', 'T'): 1,
#  ('T', 'O'): 1,
#  ('O', 'k'): 1,
#  ('k', 'e'): 1,
#  ('e', 'n'): 1,
#  ('n', 'i'): 1,
#  ('i', 'z'): 1,
#  ('z', 'e'): 1,
#  ('e', 'r'): 1,
#  (' ', 'o'): 1,
#  ('o', 'f'): 1,
#  (' ', 'G'): 1,
#  ('G', 'p'): 1,
#  ('p', 't'): 1}

# %%
def merge(ids, pair, idx):
  newids = []
  for id in ids:
    i = 0
    sub_new_id=[]
    while i < len(id):
      if i < len(id) - 1 and id[i] == pair[0] and id[i+1] == pair[1]:
        sub_new_id.append(idx)
        i += 2
      else:
        sub_new_id.append(id[i])
        i += 1
    newids.append(sub_new_id)
  return newids

# %%
ids=list(preprocessed)
utf_ids=[]
for id in ids:
    utf_ids.append(list(id.encode()))

# %%
num_merges = 1100
vocabulary_size=256
merges = {} # (int, int) -> int
for i in range(num_merges):
  stats = get_stats(utf_ids)
  try:
    pair = max(stats, key=stats.get)
  except Exception as e:
    break
  idx = 256 + i
  print(f"merging {pair} into a new token {idx}")
  utf_ids = merge(utf_ids, pair, idx)
  merges[pair] = idx
# Out:
# merging (1255, 729) into a new token 256
# merging (256, 401) into a new token 257
# merging (737, 120) into a new token 258
# merging (258, 769) into a new token 259
# merging (302, 274) into a new token 260
# merging (409, 926) into a new token 261
# merging (279, 558) into a new token 262
# merging (262, 372) into a new token 263
# merging (34, 78) into a new token 264
# merging (264, 948) into a new token 265
# merging (108, 496) into a new token 266
# merging (265, 957) into a new token 267
# merging (65, 272) into a new token 268
# merging (610, 116) into a new token 269
# merging (269, 676) into a new token 270
# merging (468, 295) into a new token 271
# merging (256, 264) into a new token 272
# merging (272, 259) into a new token 273
# merging (273, 462) into a new token 274
# merging (274, 732) into a new token 275
# merging (262, 364) into a new token 276
# merging (288, 947) into a new token 277
# merging (511, 274) into a new token 278
# merging (448, 108) into a new token 279
# merging (279, 415) into a new token 280
# merging (280, 274) into a new token 281
# merging (32, 962) into a new token 282
# merging (717, 421) into a new token 283
# merging (283, 369) into a new token 284
# merging (34, 65) into a new token 285
# merging (285, 104) into a new token 286
# merging (351, 115) into a new token 287
# merging (268, 117) into a new token 288
# merging (288, 325) into a new token 289
# merging (102, 460) into a new token 290
# merging (32, 489) into a new token 291
# merging (291, 97) into a new token 292
# merging (280, 771) into a new token 293
# merging (293, 292) into a new token 294
# merging (294, 457) into a new token 295
# merging (322, 282) into a new token 296
# merging (261, 311) into a new token 297
# merging (341, 99) into a new token 298
# merging (275, 654) into a new token 299
# merging (299, 108) into a new token 300
# merging (300, 301) into a new token 301
# merging (273, 294) into a new token 302
# merging (302, 603) into a new token 303
# merging (303, 606) into a new token 304
# merging (299, 300) into a new token 305
# merging (300, 110) into a new token 306
# merging (306, 270) into a new token 307
# merging (585, 115) into a new token 308
# merging (280, 374) into a new token 309
# merging (309, 103) into a new token 310
# merging (310, 735) into a new token 311
# merging (260, 296) into a new token 312
# merging (312, 965) into a new token 313
# merging (463, 261) into a new token 314
# merging (287, 279) into a new token 315
# merging (87, 370) into a new token 316
# merging (256, 115) into a new token 317
# merging (932, 121) into a new token 318
# merging (665, 103) into a new token 319
# merging (319, 412) into a new token 320
# merging (289, 916) into a new token 321
# merging (84, 513) into a new token 322
# merging (311, 100) into a new token 323
# merging (314, 423) into a new token 324
# merging (306, 276) into a new token 325
# merging (325, 287) into a new token 326
# merging (105, 266) into a new token 327
# merging (482, 264) into a new token 328
# merging (328, 324) into a new token 329
# merging (269, 104) into a new token 330
# merging (341, 103) into a new token 331
# merging (288, 503) into a new token 332
# merging (261, 406) into a new token 333
# merging (359, 751) into a new token 334
# merging (97, 307) into a new token 335
# merging (268, 259) into a new token 336
# merging (731, 101) into a new token 337
# merging (337, 958) into a new token 338
# merging (338, 282) into a new token 339
# merging (709, 311) into a new token 340
# merging (664, 872) into a new token 341
# merging (589, 116) into a new token 342
# merging (342, 274) into a new token 343
# merging (276, 101) into a new token 344
# merging (95, 290) into a new token 345
# merging (398, 375) into a new token 346
# merging (943, 493) into a new token 347
# merging (778, 453) into a new token 348
# merging (281, 483) into a new token 349
# merging (101, 282) into a new token 350
# merging (633, 274) into a new token 351
# merging (299, 418) into a new token 352
# merging (276, 412) into a new token 353
# merging (288, 485) into a new token 354
# merging (354, 369) into a new token 355
# merging (306, 99) into a new token 356
# merging (32, 273) into a new token 357
# merging (32, 567) into a new token 358
# merging (398, 477) into a new token 359
# merging (285, 546) into a new token 360
# merging (553, 65) into a new token 361
# merging (361, 68) into a new token 362
# merging (617, 780) into a new token 363
# merging (978, 353) into a new token 364
# merging (979, 519) into a new token 365
# merging (262, 270) into a new token 366
# merging (366, 305) into a new token 367
# merging (32, 343) into a new token 368
# merging (368, 985) into a new token 369
# merging (369, 986) into a new token 370
# merging (413, 402) into a new token 371
# merging (371, 97) into a new token 372
# merging (84, 104) into a new token 373
# merging (373, 519) into a new token 374
# merging (403, 414) into a new token 375
# merging (792, 521) into a new token 376
# merging (376, 266) into a new token 377
# merging (377, 987) into a new token 378
# merging (46, 41) into a new token 379
# merging (379, 291) into a new token 380
# merging (687, 257) into a new token 381
# merging (304, 489) into a new token 382
# merging (382, 287) into a new token 383
# merging (490, 104) into a new token 384
# merging (384, 301) into a new token 385
# merging (385, 491) into a new token 386
# merging (386, 111) into a new token 387
# merging (261, 988) into a new token 388
# merging (797, 523) into a new token 389
# merging (389, 293) into a new token 390
# merging (390, 274) into a new token 391
# merging (456, 304) into a new token 392
# merging (392, 989) into a new token 393
# merging (393, 492) into a new token 394
# merging (394, 457) into a new token 395
# merging (424, 274) into a new token 396
# merging (357, 272) into a new token 397
# merging (413, 305) into a new token 398
# merging (398, 798) into a new token 399
# merging (301, 114) into a new token 400
# merging (285, 529) into a new token 401
# merging (401, 115) into a new token 402
# merging (425, 114) into a new token 403
# merging (403, 114) into a new token 404
# merging (404, 116) into a new token 405
# merging (268, 460) into a new token 406
# merging (406, 116) into a new token 407
# merging (407, 105) into a new token 408
# merging (408, 523) into a new token 409
# merging (409, 401) into a new token 410
# merging (451, 269) into a new token 411
# merging (995, 996) into a new token 412
# merging (625, 108) into a new token 413
# merging (413, 368) into a new token 414
# merging (268, 294) into a new token 415
# merging (415, 114) into a new token 416
# merging (416, 999) into a new token 417
# merging (623, 518) into a new token 418
# merging (1001, 270) into a new token 419
# merging (553, 302) into a new token 420
# merging (1003, 532) into a new token 421
# merging (304, 1006) into a new token 422
# merging (422, 287) into a new token 423
# merging (304, 364) into a new token 424
# merging (424, 282) into a new token 425
# merging (425, 121) into a new token 426
# merging (1007, 784) into a new token 427
# merging (77, 111) into a new token 428
# merging (428, 287) into a new token 429
# merging (45, 100) into a new token 430
# merging (430, 564) into a new token 431
# merging (431, 355) into a new token 432
# merging (87, 101) into a new token 433
# merging (347, 364) into a new token 434
# merging (319, 287) into a new token 435
# merging (34, 1009) into a new token 436
# merging (33, 290) into a new token 437
# merging (101, 627) into a new token 438
# merging (275, 621) into a new token 439
# merging (439, 109) into a new token 440
# merging (1011, 297) into a new token 441
# merging (441, 302) into a new token 442
# merging (442, 428) into a new token 443
# merging (280, 447) into a new token 444
# merging (444, 274) into a new token 445
# merging (425, 109) into a new token 446
# merging (446, 429) into a new token 447
# merging (357, 120) into a new token 448
# merging (1013, 282) into a new token 449
# merging (306, 103) into a new token 450
# merging (450, 693) into a new token 451
# merging (451, 115) into a new token 452
# merging (430, 446) into a new token 453
# merging (809, 279) into a new token 454
# merging (268, 536) into a new token 455
# merging (455, 258) into a new token 456
# merging (692, 296) into a new token 457
# merging (457, 102) into a new token 458
# merging (458, 368) into a new token 459
# merging (459, 292) into a new token 460
# merging (460, 305) into a new token 461
# merging (692, 1018) into a new token 462
# merging (462, 1019) into a new token 463
# merging (284, 102) into a new token 464
# merging (288, 1006) into a new token 465
# merging (490, 108) into a new token 466
# merging (466, 381) into a new token 467
# merging (467, 797) into a new token 468
# merging (811, 1023) into a new token 469
# merging (469, 121) into a new token 470
# merging (572, 104) into a new token 471
# merging (431, 398) into a new token 472
# merging (472, 274) into a new token 473
# merging (473, 116) into a new token 474
# merging (474, 287) into a new token 475
# merging (32, 1026) into a new token 476
# merging (111, 98) into a new token 477
# merging (477, 267) into a new token 478
# merging (478, 117) into a new token 479
# merging (479, 1027) into a new token 480
# merging (631, 301) into a new token 481
# merging (481, 813) into a new token 482
# merging (330, 697) into a new token 483
# merging (483, 382) into a new token 484
# merging (400, 324) into a new token 485
# merging (485, 265) into a new token 486
# merging (256, 1029) into a new token 487
# merging (487, 301) into a new token 488
# merging (488, 305) into a new token 489
# merging (489, 816) into a new token 490
# merging (262, 287) into a new token 491
# merging (310, 265) into a new token 492
# merging (1030, 817) into a new token 493
# merging (1034, 279) into a new token 494
# merging (468, 266) into a new token 495
# merging (495, 118) into a new token 496
# merging (496, 697) into a new token 497
# merging (497, 457) into a new token 498
# merging (819, 1035) into a new token 499
# merging (499, 292) into a new token 500
# merging (633, 302) into a new token 501
# merging (501, 117) into a new token 502
# merging (502, 537) into a new token 503
# merging (275, 369) into a new token 504
# merging (504, 339) into a new token 505
# merging (505, 270) into a new token 506
# merging (699, 820) into a new token 507
# merging (1037, 115) into a new token 508
# merging (289, 504) into a new token 509
# merging (1040, 704) into a new token 510
# merging (263, 99) into a new token 511
# merging (511, 99) into a new token 512
# merging (512, 258) into a new token 513
# merging (513, 369) into a new token 514
# merging (995, 827) into a new token 515
# merging (565, 109) into a new token 516
# merging (516, 538) into a new token 517
# merging (517, 274) into a new token 518
# merging (576, 372) into a new token 519
# merging (519, 109) into a new token 520
# merging (1043, 1044) into a new token 521
# merging (636, 121) into a new token 522
# merging (406, 294) into a new token 523
# merging (279, 277) into a new token 524
# merging (524, 401) into a new token 525
# merging (383, 108) into a new token 526
# merging (526, 505) into a new token 527
# merging (380, 274) into a new token 528
# merging (100, 374) into a new token 529
# merging (529, 832) into a new token 530
# merging (427, 1047) into a new token 531
# merging (637, 279) into a new token 532
# merging (375, 300) into a new token 533
# merging (636, 101) into a new token 534
# merging (576, 263) into a new token 535
# merging (640, 832) into a new token 536
# merging (1011, 537) into a new token 537
# merging (579, 434) into a new token 538
# merging (538, 543) into a new token 539
# merging (108, 839) into a new token 540
# merging (119, 423) into a new token 541
# merging (413, 697) into a new token 542
# merging (542, 458) into a new token 543
# merging (1053, 817) into a new token 544
# merging (1055, 270) into a new token 545
# merging (280, 349) into a new token 546
# merging (714, 460) into a new token 547
# merging (547, 715) into a new token 548
# merging (436, 717) into a new token 549
# merging (530, 344) into a new token 550
# merging (275, 311) into a new token 551
# merging (551, 279) into a new token 552
# merging (705, 446) into a new token 553
# merging (553, 109) into a new token 554
# merging (554, 301) into a new token 555
# merging (581, 309) into a new token 556
# merging (556, 460) into a new token 557
# merging (557, 582) into a new token 558
# merging (845, 112) into a new token 559
# merging (559, 295) into a new token 560
# merging (846, 358) into a new token 561
# merging (561, 114) into a new token 562
# merging (562, 847) into a new token 563
# merging (719, 304) into a new token 564
# merging (564, 292) into a new token 565
# merging (1062, 292) into a new token 566
# merging (1063, 101) into a new token 567
# merging (289, 267) into a new token 568
# merging (568, 411) into a new token 569
# merging (565, 97) into a new token 570
# merging (275, 305) into a new token 571
# merging (571, 109) into a new token 572
# merging (850, 1067) into a new token 573
# merging (262, 722) into a new token 574
# merging (574, 414) into a new token 575
# merging (978, 305) into a new token 576
# merging (452, 723) into a new token 577
# merging (577, 274) into a new token 578
# merging (851, 97) into a new token 579
# merging (579, 847) into a new token 580
# merging (280, 266) into a new token 581
# merging (581, 346) into a new token 582
# merging (582, 1068) into a new token 583
# merging (259, 713) into a new token 584
# merging (34, 58) into a new token 585
# merging (1071, 343) into a new token 586
# merging (306, 510) into a new token 587
# merging (587, 258) into a new token 588
# merging (588, 512) into a new token 589
# merging (110, 724) into a new token 590
# merging (268, 274) into a new token 591
# merging (1073, 270) into a new token 592
# merging (1074, 271) into a new token 593
# merging (620, 331) into a new token 594
# merging (594, 543) into a new token 595
# merging (384, 264) into a new token 596
# merging (596, 725) into a new token 597
# merging (306, 817) into a new token 598
# merging (854, 644) into a new token 599
# merging (475, 1075) into a new token 600
# merging (476, 691) into a new token 601
# merging (256, 727) into a new token 602
# merging (602, 117) into a new token 603
# merging (603, 462) into a new token 604
# merging (604, 477) into a new token 605
# merging (1076, 394) into a new token 606
# merging (797, 302) into a new token 607
# merging (607, 1077) into a new token 608
# merging (855, 529) into a new token 609
# merging (609, 112) into a new token 610
# merging (610, 513) into a new token 611
# merging (1079, 697) into a new token 612
# merging (612, 114) into a new token 613
# merging (613, 428) into a new token 614
# merging (438, 111) into a new token 615
# merging (615, 434) into a new token 616
# merging (268, 856) into a new token 617
# merging (617, 270) into a new token 618
# merging (32, 302) into a new token 619
# merging (619, 647) into a new token 620
# merging (620, 402) into a new token 621
# merging (621, 514) into a new token 622
# merging (1080, 1081) into a new token 623
# merging (623, 857) into a new token 624
# merging (427, 500) into a new token 625
# merging (625, 274) into a new token 626
# merging (862, 478) into a new token 627
# merging (627, 264) into a new token 628
# merging (628, 512) into a new token 629
# merging (1082, 264) into a new token 630
# merging (630, 408) into a new token 631
# merging (631, 105) into a new token 632
# merging (632, 305) into a new token 633
# merging (400, 117) into a new token 634
# merging (634, 261) into a new token 635
# merging (268, 1089) into a new token 636
# merging (468, 101) into a new token 637
# merging (637, 103) into a new token 638
# merging (638, 408) into a new token 639
# merging (273, 479) into a new token 640
# merging (846, 512) into a new token 641
# merging (452, 985) into a new token 642
# merging (642, 270) into a new token 643
# merging (1053, 300) into a new token 644
# merging (644, 512) into a new token 645
# merging (1080, 1091) into a new token 646
# merging (45, 648) into a new token 647
# merging (647, 270) into a new token 648
# merging (648, 274) into a new token 649
# merging (430, 297) into a new token 650
# merging (650, 115) into a new token 651
# merging (651, 109) into a new token 652
# merging (652, 504) into a new token 653
# merging (285, 117) into a new token 654
# merging (654, 120) into a new token 655
# merging (655, 869) into a new token 656
# merging (731, 275) into a new token 657
# merging (657, 270) into a new token 658
# merging (306, 108) into a new token 659
# merging (659, 271) into a new token 660
# merging (660, 732) into a new token 661
# merging (256, 100) into a new token 662
# merging (662, 316) into a new token 663
# merging (663, 102) into a new token 664
# merging (664, 101) into a new token 665
# merging (665, 872) into a new token 666
# merging (1074, 1094) into a new token 667
# merging (403, 277) into a new token 668
# merging (668, 97) into a new token 669
# merging (669, 708) into a new token 670
# merging (670, 512) into a new token 671
# merging (508, 287) into a new token 672
# merging (672, 122) into a new token 673
# merging (673, 292) into a new token 674
# merging (819, 114) into a new token 675
# merging (675, 1101) into a new token 676
# merging (676, 458) into a new token 677
# merging (273, 292) into a new token 678
# merging (678, 112) into a new token 679
# merging (679, 111) into a new token 680
# merging (680, 307) into a new token 681
# merging (536, 523) into a new token 682
# merging (682, 343) into a new token 683
# merging (306, 115) into a new token 684
# merging (684, 496) into a new token 685
# merging (685, 99) into a new token 686
# merging (686, 292) into a new token 687
# merging (873, 1089) into a new token 688
# merging (1102, 1044) into a new token 689
# merging (862, 1075) into a new token 690
# merging (258, 120) into a new token 691
# merging (691, 480) into a new token 692
# merging (705, 1105) into a new token 693
# merging (326, 118) into a new token 694
# merging (694, 649) into a new token 695
# merging (1106, 308) into a new token 696
# merging (1003, 267) into a new token 697
# merging (697, 514) into a new token 698
# merging (632, 111) into a new token 699
# merging (699, 588) into a new token 700
# merging (700, 270) into a new token 701
# merging (285, 593) into a new token 702
# merging (702, 99) into a new token 703
# merging (703, 257) into a new token 704
# merging (704, 287) into a new token 705
# merging (850, 457) into a new token 706
# merging (400, 593) into a new token 707
# merging (299, 328) into a new token 708
# merging (708, 274) into a new token 709
# merging (452, 734) into a new token 710
# merging (710, 277) into a new token 711
# merging (711, 735) into a new token 712
# merging (268, 293) into a new token 713
# merging (713, 875) into a new token 714
# merging (714, 279) into a new token 715
# merging (1109, 267) into a new token 716
# merging (716, 477) into a new token 717
# merging (341, 109) into a new token 718
# merging (80, 805) into a new token 719
# merging (280, 546) into a new token 720
# merging (427, 879) into a new token 721
# merging (721, 117) into a new token 722
# merging (722, 458) into a new token 723
# merging (736, 423) into a new token 724
# merging (306, 882) into a new token 725
# merging (725, 270) into a new token 726
# merging (286, 879) into a new token 727
# merging (273, 276) into a new token 728
# merging (728, 449) into a new token 729
# merging (650, 435) into a new token 730
# merging (730, 300) into a new token 731
# merging (1113, 648) into a new token 732
# merging (732, 292) into a new token 733
# merging (579, 106) into a new token 734
# merging (734, 117) into a new token 735
# merging (735, 103) into a new token 736
# merging (736, 305) into a new token 737
# merging (598, 98) into a new token 738
# merging (738, 875) into a new token 739
# merging (599, 118) into a new token 740
# merging (740, 496) into a new token 741
# merging (811, 111) into a new token 742
# merging (263, 822) into a new token 743
# merging (743, 279) into a new token 744
# merging (384, 272) into a new token 745
# merging (626, 272) into a new token 746
# merging (483, 1120) into a new token 747
# merging (747, 101) into a new token 748
# merging (1123, 115) into a new token 749
# merging (256, 99) into a new token 750
# merging (750, 277) into a new token 751
# merging (751, 295) into a new token 752
# merging (873, 121) into a new token 753
# merging (261, 835) into a new token 754
# merging (330, 117) into a new token 755
# merging (755, 646) into a new token 756
# merging (528, 121) into a new token 757
# merging (576, 116) into a new token 758
# merging (758, 343) into a new token 759
# merging (598, 295) into a new token 760
# merging (256, 457) into a new token 761
# merging (653, 630) into a new token 762
# merging (303, 544) into a new token 763
# merging (888, 108) into a new token 764
# merging (764, 267) into a new token 765
# merging (542, 265) into a new token 766
# merging (766, 274) into a new token 767
# merging (260, 496) into a new token 768
# merging (291, 891) into a new token 769
# merging (769, 282) into a new token 770
# merging (631, 285) into a new token 771
# merging (341, 647) into a new token 772
# merging (742, 603) into a new token 773
# merging (773, 272) into a new token 774
# merging (1130, 333) into a new token 775
# merging (290, 272) into a new token 776
# merging (776, 725) into a new token 777
# merging (256, 274) into a new token 778
# merging (778, 101) into a new token 779
# merging (482, 704) into a new token 780
# merging (276, 264) into a new token 781
# merging (781, 1131) into a new token 782
# merging (259, 118) into a new token 783
# merging (783, 293) into a new token 784
# merging (656, 593) into a new token 785
# merging (71, 602) into a new token 786
# merging (786, 813) into a new token 787
# merging (744, 725) into a new token 788
# merging (285, 478) into a new token 789
# merging (789, 112) into a new token 790
# merging (340, 103) into a new token 791
# merging (791, 300) into a new token 792
# merging (581, 297) into a new token 793
# merging (793, 105) into a new token 794
# merging (794, 294) into a new token 795
# merging (279, 259) into a new token 796
# merging (796, 274) into a new token 797
# merging (894, 1140) into a new token 798
# merging (104, 276) into a new token 799
# merging (315, 895) into a new token 800
# merging (800, 538) into a new token 801
# merging (801, 279) into a new token 802
# merging (32, 374) into a new token 803
# merging (803, 896) into a new token 804
# merging (1143, 98) into a new token 805
# merging (805, 897) into a new token 806
# merging (806, 115) into a new token 807
# merging (260, 588) into a new token 808
# merging (104, 898) into a new token 809
# merging (452, 106) into a new token 810
# merging (810, 111) into a new token 811
# merging (811, 121) into a new token 812
# merging (438, 532) into a new token 813
# merging (581, 304) into a new token 814
# merging (814, 480) into a new token 815
# merging (660, 297) into a new token 816
# merging (816, 1151) into a new token 817
# merging (102, 1152) into a new token 818
# merging (818, 261) into a new token 819
# merging (45, 308) into a new token 820
# merging (820, 434) into a new token 821
# merging (413, 1153) into a new token 822
# merging (900, 101) into a new token 823
# merging (823, 661) into a new token 824
# merging (456, 292) into a new token 825
# merging (279, 328) into a new token 826
# merging (826, 276) into a new token 827
# merging (827, 107) into a new token 828
# merging (904, 294) into a new token 829
# merging (829, 115) into a new token 830
# merging (280, 847) into a new token 831
# merging (742, 328) into a new token 832
# merging (832, 292) into a new token 833
# merging (905, 276) into a new token 834
# merging (283, 627) into a new token 835
# merging (380, 261) into a new token 836
# merging (347, 446) into a new token 837
# merging (579, 727) into a new token 838
# merging (838, 318) into a new token 839
# merging (288, 1105) into a new token 840
# merging (840, 270) into a new token 841
# merging (263, 112) into a new token 842
# merging (842, 277) into a new token 843
# merging (1157, 277) into a new token 844
# merging (844, 512) into a new token 845
# merging (280, 267) into a new token 846
# merging (427, 1081) into a new token 847
# merging (109, 121) into a new token 848
# merging (1164, 751) into a new token 849
# merging (319, 264) into a new token 850
# merging (850, 908) into a new token 851
# merging (633, 305) into a new token 852
# merging (852, 274) into a new token 853
# merging (299, 297) into a new token 854
# merging (45, 264) into a new token 855
# merging (855, 305) into a new token 856
# merging (856, 107) into a new token 857
# merging (1168, 117) into a new token 858
# merging (858, 276) into a new token 859
# merging (859, 732) into a new token 860
# merging (398, 109) into a new token 861
# merging (861, 111) into a new token 862
# merging (862, 264) into a new token 863
# merging (256, 302) into a new token 864
# merging (864, 293) into a new token 865
# merging (865, 348) into a new token 866
# merging (866, 279) into a new token 867
# merging (285, 265) into a new token 868
# merging (868, 1169) into a new token 869
# merging (555, 270) into a new token 870
# merging (289, 754) into a new token 871
# merging (285, 267) into a new token 872
# merging (911, 300) into a new token 873
# merging (640, 501) into a new token 874
# merging (403, 1035) into a new token 875
# merging (875, 1170) into a new token 876
# merging (359, 1018) into a new token 877
# merging (877, 265) into a new token 878
# merging (878, 272) into a new token 879
# merging (360, 101) into a new token 880
# merging (880, 292) into a new token 881
# merging (310, 105) into a new token 882
# merging (882, 261) into a new token 883
# merging (260, 489) into a new token 884
# merging (1176, 757) into a new token 885
# merging (268, 300) into a new token 886
# merging (886, 372) into a new token 887
# merging (32, 69) into a new token 888
# merging (888, 109) into a new token 889
# merging (889, 914) into a new token 890
# merging (890, 999) into a new token 891
# merging (283, 271) into a new token 892
# merging (262, 489) into a new token 893
# merging (330, 908) into a new token 894
# merging (641, 374) into a new token 895
# merging (515, 724) into a new token 896
# merging (896, 116) into a new token 897
# merging (897, 97) into a new token 898
# merging (262, 121) into a new token 899
# merging (899, 109) into a new token 900
# merging (900, 112) into a new token 901
# merging (901, 104) into a new token 902
# merging (902, 115) into a new token 903
# merging (409, 896) into a new token 904
# merging (605, 305) into a new token 905
# merging (905, 355) into a new token 906
# merging (259, 304) into a new token 907
# merging (907, 104) into a new token 908
# merging (285, 324) into a new token 909
# merging (909, 274) into a new token 910
# merging (73, 110) into a new token 911
# merging (1179, 109) into a new token 912
# merging (912, 343) into a new token 913
# merging (288, 642) into a new token 914
# merging (914, 282) into a new token 915
# merging (273, 265) into a new token 916
# merging (916, 100) into a new token 917
# merging (917, 111) into a new token 918
# merging (918, 294) into a new token 919
# merging (536, 270) into a new token 920
# merging (576, 102) into a new token 921
# merging (921, 353) into a new token 922
# merging (922, 292) into a new token 923
# merging (279, 744) into a new token 924
# merging (924, 117) into a new token 925
# merging (925, 986) into a new token 926
# merging (280, 1152) into a new token 927
# merging (927, 105) into a new token 928
# merging (928, 300) into a new token 929
# merging (263, 118) into a new token 930
# merging (930, 305) into a new token 931
# merging (1181, 1153) into a new token 932
# merging (1183, 457) into a new token 933
# merging (1123, 270) into a new token 934
# merging (392, 108) into a new token 935
# merging (935, 667) into a new token 936
# merging (279, 916) into a new token 937
# merging (262, 349) into a new token 938
# merging (938, 305) into a new token 939
# merging (515, 903) into a new token 940
# merging (329, 489) into a new token 941
# merging (106, 418) into a new token 942
# merging (942, 259) into a new token 943
# merging (943, 603) into a new token 944
# merging (944, 266) into a new token 945
# merging (1062, 107) into a new token 946
# merging (258, 122) into a new token 947
# merging (947, 901) into a new token 948
# merging (948, 276) into a new token 949
# merging (73, 102) into a new token 950
# merging (32, 85) into a new token 951
# merging (951, 723) into a new token 952
# merging (952, 537) into a new token 953
# merging (288, 277) into a new token 954
# merging (954, 1193) into a new token 955
# merging (1194, 294) into a new token 956
# merging (287, 337) into a new token 957
# merging (957, 305) into a new token 958
# merging (268, 287) into a new token 959
# merging (959, 478) into a new token 960
# merging (960, 293) into a new token 961
# merging (961, 305) into a new token 962
# merging (539, 107) into a new token 963
# merging (887, 277) into a new token 964
# merging (964, 333) into a new token 965
# merging (965, 1170) into a new token 966
# merging (1043, 358) into a new token 967
# merging (967, 265) into a new token 968
# merging (968, 270) into a new token 969
# merging (45, 734) into a new token 970
# merging (289, 300) into a new token 971
# merging (971, 304) into a new token 972
# merging (972, 378) into a new token 973
# merging (973, 285) into a new token 974
# merging (974, 301) into a new token 975
# merging (929, 816) into a new token 976
# merging (288, 600) into a new token 977
# merging (281, 115) into a new token 978
# merging (978, 267) into a new token 979
# merging (979, 582) into a new token 980
# merging (407, 103) into a new token 981
# merging (981, 117) into a new token 982
# merging (982, 896) into a new token 983
# merging (258, 601) into a new token 984
# merging (984, 304) into a new token 985
# merging (985, 816) into a new token 986
# merging (420, 264) into a new token 987
# merging (987, 270) into a new token 988
# merging (988, 479) into a new token 989
# merging (989, 267) into a new token 990
# merging (990, 458) into a new token 991
# merging (579, 115) into a new token 992
# merging (992, 478) into a new token 993
# merging (993, 109) into a new token 994
# merging (994, 546) into a new token 995
# merging (261, 107) into a new token 996
# merging (996, 402) into a new token 997
# merging (760, 270) into a new token 998
# merging (1203, 1204) into a new token 999
# merging (306, 305) into a new token 1000
# merging (273, 353) into a new token 1001
# merging (1001, 259) into a new token 1002
# merging (1002, 368) into a new token 1003
# merging (420, 116) into a new token 1004
# merging (1004, 116) into a new token 1005
# merging (1005, 121) into a new token 1006
# merging (468, 1023) into a new token 1007
# merging (1007, 1206) into a new token 1008
# merging (279, 333) into a new token 1009
# merging (1009, 97) into a new token 1010
# merging (1010, 435) into a new token 1011
# merging (420, 882) into a new token 1012
# merging (1012, 274) into a new token 1013
# merging (461, 897) into a new token 1014
# merging (261, 471) into a new token 1015
# merging (1015, 505) into a new token 1016
# merging (739, 109) into a new token 1017
# merging (1017, 274) into a new token 1018
# merging (1183, 558) into a new token 1019
# merging (1019, 279) into a new token 1020
# merging (507, 103) into a new token 1021
# merging (1021, 331) into a new token 1022
# merging (1022, 272) into a new token 1023
# merging (285, 293) into a new token 1024
# merging (456, 353) into a new token 1025
# merging (1025, 117) into a new token 1026
# merging (1026, 305) into a new token 1027
# merging (1193, 295) into a new token 1028
# merging (1209, 116) into a new token 1029
# merging (1029, 117) into a new token 1030
# merging (1030, 910) into a new token 1031
# merging (1210, 343) into a new token 1032
# merging (475, 563) into a new token 1033
# merging (1033, 266) into a new token 1034
# merging (1034, 283) into a new token 1035
# merging (900, 649) into a new token 1036
# merging (1036, 1211) into a new token 1037
# merging (275, 483) into a new token 1038
# merging (1212, 931) into a new token 1039
# merging (268, 353) into a new token 1040
# merging (1040, 99) into a new token 1041
# merging (1041, 813) into a new token 1042
# merging (288, 429) into a new token 1043
# merging (1043, 343) into a new token 1044
# merging (1044, 274) into a new token 1045
# merging (32, 263) into a new token 1046
# merging (1046, 259) into a new token 1047
# merging (1047, 115) into a new token 1048
# merging (846, 564) into a new token 1049
# merging (1049, 274) into a new token 1050
# merging (594, 302) into a new token 1051
# merging (1051, 1213) into a new token 1052
# merging (1191, 274) into a new token 1053
# merging (731, 349) into a new token 1054
# merging (1054, 270) into a new token 1055
# merging (862, 353) into a new token 1056
# merging (515, 108) into a new token 1057
# merging (1057, 393) into a new token 1058
# merging (932, 301) into a new token 1059
# merging (1076, 1214) into a new token 1060
# merging (1060, 115) into a new token 1061
# merging (1130, 487) into a new token 1062
# merging (347, 1214) into a new token 1063
# merging (359, 109) into a new token 1064
# merging (1064, 324) into a new token 1065
# merging (1217, 118) into a new token 1066
# merging (1066, 514) into a new token 1067
# merging (1210, 279) into a new token 1068
# merging (115, 1221) into a new token 1069
# merging (1069, 279) into a new token 1070
# merging (285, 695) into a new token 1071
# merging (300, 265) into a new token 1072
# merging (261, 1221) into a new token 1073
# merging (1073, 757) into a new token 1074
# merging (1073, 457) into a new token 1075
# merging (288, 293) into a new token 1076
# merging (1076, 266) into a new token 1077
# merging (1077, 996) into a new token 1078
# merging (714, 1228) into a new token 1079
# merging (1229, 292) into a new token 1080
# merging (1080, 1228) into a new token 1081
# merging (913, 305) into a new token 1082
# merging (851, 798) into a new token 1083
# merging (280, 321) into a new token 1084
# merging (1084, 116) into a new token 1085
# merging (1085, 264) into a new token 1086
# merging (1086, 751) into a new token 1087
# merging (289, 649) into a new token 1088
# merging (1088, 104) into a new token 1089
# merging (1089, 111) into a new token 1090
# merging (1090, 277) into a new token 1091
# merging (65, 115) into a new token 1092
# merging (409, 99) into a new token 1093
# merging (1093, 673) into a new token 1094
# merging (1094, 115) into a new token 1095
# merging (1209, 263) into a new token 1096
# merging (1096, 434) into a new token 1097
# merging (1097, 277) into a new token 1098
# merging (1232, 1233) into a new token 1099
# merging (283, 294) into a new token 1100
# merging (936, 257) into a new token 1101
# merging (1101, 302) into a new token 1102
# merging (436, 297) into a new token 1103
# merging (1234, 116) into a new token 1104
# merging (280, 432) into a new token 1105
# merging (1105, 758) into a new token 1106
# merging (1215, 270) into a new token 1107
# merging (933, 493) into a new token 1108
# merging (261, 344) into a new token 1109
# merging (515, 287) into a new token 1110
# merging (1110, 1237) into a new token 1111
# merging (268, 265) into a new token 1112
# merging (1112, 264) into a new token 1113
# merging (1113, 304) into a new token 1114
# merging (1114, 257) into a new token 1115
# merging (261, 600) into a new token 1116
# merging (1239, 392) into a new token 1117
# merging (1117, 114) into a new token 1118
# merging (942, 279) into a new token 1119
# merging (943, 118) into a new token 1120
# merging (1120, 1151) into a new token 1121
# merging (873, 114) into a new token 1122
# merging (1102, 1242) into a new token 1123
# merging (1243, 832) into a new token 1124
# merging (629, 355) into a new token 1125
# merging (1244, 435) into a new token 1126
# merging (1126, 274) into a new token 1127
# merging (499, 111) into a new token 1128
# merging (927, 279) into a new token 1129
# merging (1245, 274) into a new token 1130
# merging (67, 414) into a new token 1131
# merging (533, 270) into a new token 1132
# merging (1232, 477) into a new token 1133
# merging (1082, 315) into a new token 1134
# merging (1134, 297) into a new token 1135
# merging (273, 511) into a new token 1136
# merging (581, 101) into a new token 1137
# merging (1137, 946) into a new token 1138
# merging (850, 654) into a new token 1139
# merging (1139, 292) into a new token 1140
# merging (279, 1248) into a new token 1141
# merging (515, 947) into a new token 1142
# merging (1142, 116) into a new token 1143
# merging (1143, 115) into a new token 1144
# merging (256, 331) into a new token 1145
# merging (1145, 115) into a new token 1146
# merging (1146, 282) into a new token 1147
# merging (660, 1248) into a new token 1148
# merging (1148, 292) into a new token 1149
# merging (1066, 120) into a new token 1150
# merging (650, 523) into a new token 1151
# merging (1151, 1249) into a new token 1152
# merging (1152, 582) into a new token 1153
# merging (268, 402) into a new token 1154
# merging (1154, 292) into a new token 1155
# merging (1155, 752) into a new token 1156
# merging (1156, 266) into a new token 1157
# merging (279, 265) into a new token 1158
# merging (1158, 343) into a new token 1159
# merging (1159, 301) into a new token 1160
# merging (740, 291) into a new token 1161
# merging (1161, 121) into a new token 1162
# merging (439, 948) into a new token 1163
# merging (275, 342) into a new token 1164
# merging (427, 769) into a new token 1165
# merging (1113, 98) into a new token 1166
# merging (1166, 504) into a new token 1167
# merging (289, 897) into a new token 1168
# merging (1168, 274) into a new token 1169
# merging (617, 264) into a new token 1170
# merging (379, 263) into a new token 1171
# merging (936, 295) into a new token 1172
# merging (1172, 277) into a new token 1173
# merging (289, 1252) into a new token 1174
# merging (407, 1252) into a new token 1175
# merging (436, 269) into a new token 1176
# merging (1176, 311) into a new token 1177
# merging (66, 266) into a new token 1178
# merging (1203, 491) into a new token 1179
# merging (1179, 110) into a new token 1180
# merging (1180, 529) into a new token 1181
# merging (1181, 269) into a new token 1182
# merging (340, 646) into a new token 1183
# merging (1183, 725) into a new token 1184
# merging (617, 99) into a new token 1185
# merging (1185, 107) into a new token 1186
# merging (687, 559) into a new token 1187
# merging (285, 754) into a new token 1188
# merging (436, 260) into a new token 1189
# merging (279, 300) into a new token 1190
# merging (1190, 107) into a new token 1191
# merging (605, 1211) into a new token 1192
# merging (261, 346) into a new token 1193
# merging (1193, 503) into a new token 1194
# merging (436, 487) into a new token 1195
# merging (1195, 121) into a new token 1196
# merging (101, 646) into a new token 1197
# merging (1197, 394) into a new token 1198
# merging (1198, 115) into a new token 1199
# merging (34, 59) into a new token 1200
# merging (508, 301) into a new token 1201
# merging (45, 97) into a new token 1202
# merging (45, 98) into a new token 1203
# merging (1203, 114) into a new token 1204
# merging (1204, 304) into a new token 1205
# merging (262, 375) into a new token 1206
# merging (258, 294) into a new token 1207
# merging (900, 296) into a new token 1208
# merging (1208, 100) into a new token 1209
# merging (1209, 117) into a new token 1210
# merging (1210, 827) into a new token 1211
# merging (320, 634) into a new token 1212
# merging (1212, 279) into a new token 1213
# merging (558, 485) into a new token 1214
# merging (436, 415) into a new token 1215
# merging (261, 955) into a new token 1216
# merging (956, 270) into a new token 1217
# merging (330, 601) into a new token 1218
# merging (1218, 105) into a new token 1219
# merging (1219, 111) into a new token 1220
# merging (260, 414) into a new token 1221
# merging (315, 818) into a new token 1222
# merging (1222, 504) into a new token 1223
# merging (280, 259) into a new token 1224
# merging (1224, 305) into a new token 1225
# merging (1225, 428) into a new token 1226
# merging (404, 638) into a new token 1227
# merging (1229, 287) into a new token 1228
# merging (430, 505) into a new token 1229
# merging (258, 462) into a new token 1230
# merging (1230, 377) into a new token 1231
# merging (1231, 428) into a new token 1232
# merging (508, 603) into a new token 1233
# merging (1233, 102) into a new token 1234
# merging (1234, 279) into a new token 1235
# merging (547, 114) into a new token 1236
# merging (549, 282) into a new token 1237
# merging (515, 111) into a new token 1238
# merging (1238, 266) into a new token 1239
# merging (588, 611) into a new token 1240
# merging (579, 1237) into a new token 1241
# merging (275, 758) into a new token 1242
# merging (297, 121) into a new token 1243
# merging (256, 267) into a new token 1244
# merging (605, 771) into a new token 1245
# merging (259, 958) into a new token 1246
# merging (1246, 557) into a new token 1247
# merging (1247, 510) into a new token 1248
# merging (1248, 270) into a new token 1249
# merging (819, 111) into a new token 1250
# merging (1250, 1026) into a new token 1251
# merging (1244, 364) into a new token 1252
# merging (404, 946) into a new token 1253
# merging (263, 638) into a new token 1254
# merging (1194, 931) into a new token 1255
# merging (920, 274) into a new token 1256
# merging (400, 275) into a new token 1257
# merging (34, 66) into a new token 1258
# merging (1258, 121) into a new token 1259
# merging (674, 401) into a new token 1260
# merging (1106, 293) into a new token 1261
# merging (404, 278) into a new token 1262
# merging (438, 444) into a new token 1263
# merging (1263, 279) into a new token 1264
# merging (894, 423) into a new token 1265
# merging (301, 446) into a new token 1266
# merging (548, 122) into a new token 1267
# merging (1267, 277) into a new token 1268
# merging (285, 259) into a new token 1269
# merging (1269, 292) into a new token 1270
# merging (285, 880) into a new token 1271
# merging (1271, 121) into a new token 1272
# merging (289, 780) into a new token 1273
# merging (261, 108) into a new token 1274
# merging (1274, 305) into a new token 1275
# merging (1275, 279) into a new token 1276
# merging (260, 898) into a new token 1277
# merging (256, 801) into a new token 1278
# merging (1278, 120) into a new token 1279
# merging (1279, 857) into a new token 1280
# merging (332, 109) into a new token 1281
# merging (1281, 267) into a new token 1282
# merging (116, 402) into a new token 1283
# merging (894, 370) into a new token 1284
# merging (536, 97) into a new token 1285
# merging (1285, 122) into a new token 1286
# merging (1286, 101) into a new token 1287
# merging (1287, 735) into a new token 1288
# merging (32, 292) into a new token 1289
# merging (1289, 99) into a new token 1290
# merging (1290, 780) into a new token 1291
# merging (1291, 101) into a new token 1292
# merging (258, 119) into a new token 1293
# merging (1293, 290) into a new token 1294
# merging (899, 330) into a new token 1295
# merging (1295, 287) into a new token 1296
# merging (97, 104) into a new token 1297
# merging (297, 264) into a new token 1298
# merging (576, 99) into a new token 1299
# merging (1299, 108) into a new token 1300
# merging (1300, 97) into a new token 1301
# merging (1301, 260) into a new token 1302
# merging (682, 757) into a new token 1303
# merging (111, 102) into a new token 1304
# merging (298, 274) into a new token 1305
# merging (275, 315) into a new token 1306
# merging (1306, 108) into a new token 1307
# merging (1307, 349) into a new token 1308
# merging (736, 276) into a new token 1309
# merging (687, 423) into a new token 1310
# merging (442, 293) into a new token 1311
# merging (1311, 401) into a new token 1312
# merging (413, 307) into a new token 1313
# merging (311, 115) into a new token 1314
# merging (34, 962) into a new token 1315
# merging (290, 298) into a new token 1316
# merging (664, 480) into a new token 1317
# merging (413, 111) into a new token 1318
# merging (1318, 820) into a new token 1319
# merging (34, 669) into a new token 1320
# merging (346, 532) into a new token 1321
# merging (317, 876) into a new token 1322
# merging (1322, 857) into a new token 1323
# merging (99, 286) into a new token 1324
# merging (1324, 110) into a new token 1325
# merging (298, 270) into a new token 1326
# merging (288, 323) into a new token 1327
# merging (99, 323) into a new token 1328
# merging (70, 293) into a new token 1329
# merging (1040, 261) into a new token 1330
# merging (1030, 297) into a new token 1331
# merging (1331, 292) into a new token 1332
# merging (261, 1131) into a new token 1333
# merging (714, 327) into a new token 1334
# merging (262, 330) into a new token 1335
# merging (778, 931) into a new token 1336
# merging (281, 355) into a new token 1337
# merging (911, 503) into a new token 1338
# merging (1338, 116) into a new token 1339
# merging (1339, 434) into a new token 1340
# merging (331, 724) into a new token 1341
# merging (1341, 879) into a new token 1342
# merging (303, 601) into a new token 1343
# merging (1343, 100) into a new token 1344
# merging (1344, 823) into a new token 1345
# merging (278, 967) into a new token 1346
# merging (340, 115) into a new token 1347
# merging (1347, 769) into a new token 1348
# merging (1217, 278) into a new token 1349
# merging (260, 343) into a new token 1350
# merging (1350, 311) into a new token 1351
# merging (320, 103) into a new token 1352
# merging (1352, 271) into a new token 1353
# merging (1353, 377) into a new token 1354
# merging (1354, 270) into a new token 1355

# %%
import regex as re

class GPT4Tokenizer:
    def __init__(self, merge):
        self.byte_to_token = {}
        self.token_to_byte = {}
        self.mergepair_to_byte = {}
        self.byte_to_mergepair = {}

        for i in range(0, 256):
            self.byte_to_token[i] = i
            self.token_to_byte[i] = i

        for pair, new_byte in merge.items():
            self.byte_to_mergepair[new_byte] = pair
            self.mergepair_to_byte[pair] = new_byte
            self.byte_to_token[new_byte] = new_byte
            self.token_to_byte[new_byte] = new_byte

        special_token_id = len(self.byte_to_token)
        self.byte_to_token["<|endoftext|>"] = special_token_id
        self.token_to_byte[special_token_id] = "<|endoftext|>"
        self.special_token_id = special_token_id

        self.pat = re.compile(
            r"""'(?i:[sdmt]|ll|ve|re)|[^\r\n\p{L}\p{N}]?+\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]++[\r\n]*|\s*[\r\n]|\s+(?!\S)|\s+"""
        )

    def encode(self, text, add_special_token=False):
        words = re.findall(self.pat, text)
        words_in_bytes = [list(word.encode("utf-8")) for word in words]

        encoded_tokens = []

        for word in words_in_bytes:

            while len(word) > 1:

                best_pair = None
                best_idx = float('inf')
                
                for i in range(len(word) - 1):
                    pair = (word[i], word[i + 1])
                    if pair in self.mergepair_to_byte:

                        merge_idx = self.mergepair_to_byte[pair]
                        if merge_idx < best_idx:
                            best_idx = merge_idx
                            best_pair = pair
                
                if best_pair is None:
                    break
                
                new_word = []
                i = 0
                while i < len(word):
                    if (i < len(word) - 1 and 
                        word[i] == best_pair[0] and 
                        word[i + 1] == best_pair[1]):
                        new_word.append(self.mergepair_to_byte[best_pair])
                        i += 2
                    else:
                        new_word.append(word[i])
                        i += 1
                
                word = new_word

            encoded_tokens.extend(word)
        
        if add_special_token:
            encoded_tokens.append(self.special_token_id)
        
        return encoded_tokens

    def merged_token(self, pair, decode_ids=None):
        if decode_ids is None:
            decode_ids = []

        first, second = pair

        if first > 255:
            self.merged_token(self.byte_to_mergepair[first], decode_ids)
        else:
            decode_ids.append(first)

        if second > 255:
            self.merged_token(self.byte_to_mergepair[second], decode_ids)
        else:
            decode_ids.append(second)

        return decode_ids

    def decode(self, ids):
        decoded_bytes = []
        
        for id in ids:
            if id not in self.token_to_byte:
                raise ValueError(f"Unknown token ID: {id}")
            
            tid = self.token_to_byte[id]
            
            if isinstance(tid, str):
                continue  
            
            if tid > 255 and tid in self.byte_to_mergepair:
                pair = self.byte_to_mergepair[tid]
                base_utf = self.merged_token(pair)
                decoded_bytes.extend(base_utf)
            else:
                decoded_bytes.append(tid)
        
        return bytes(decoded_bytes).decode("utf-8", errors="replace")

# %%
tokenizer=GPT4Tokenizer(merges)

# %%
text = "Build GPT4Tokenizer From Sratch"
tokens = tokenizer.encode(text)
print(f"Encoded: {tokens}")
decoded = tokenizer.decode(tokens)
print(f"Decoded: {decoded}")
# Out:
# Encoded: [66, 117, 105, 108, 100, 32, 71, 80, 84, 52, 84, 111, 107, 101, 110, 105, 122, 101, 114, 32, 70, 114, 111, 109, 32, 83, 114, 97, 116, 99, 104]
# Decoded: Build GPT4Tokenizer From Sratch
